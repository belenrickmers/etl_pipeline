# %%
# %pip install pydantic
# Out:
# Looking in indexes: https://pypi.org/simple, https://SESA802838:****@global-artifacts.se.com/artifactory/api/pypi/se_aai-python-prod-local/simple/, https://SESA802838:****@global-artifacts.se.com/artifactory/api/pypi/sd-aihub-common-pypi-prod-fed/simple/
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------------ --- 1.8/2.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.5 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import sys, os
sys.path.insert(0, os.path.abspath("."))
import importlib
from etl.extract import call_api
from etl import models
from etl.utils import load_env_variables
importlib.reload(models)
CoinMarketData = models.CoinMarketData



load_env_variables()
COINGECKO_API_URL = os.getenv("COINGECKO_API_URL")

# %%
print(COINGECKO_API_URL)
# Out:
# https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=100

# %%
response = call_api(COINGECKO_API_URL)
# Out:
# 2026-03-20 11:20:42.517 | INFO     | etl.extract:call_api:20 - API call successful: 200

# %%
response[8]
# Out:
# {'id': 'figure-heloc',
#  'symbol': 'figr_heloc',
#  'name': 'Figure Heloc',
#  'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#  'current_price': 1.002,
#  'market_cap': 15871206322,
#  'market_cap_rank': 9,
#  'fully_diluted_valuation': 15871206322,
#  'total_volume': 331240164,
#  'high_24h': 1.033,
#  'low_24h': 1.002,
#  'price_change_24h': -0.023155999999999954,
#  'price_change_percentage_24h': -2.25934,
#  'market_cap_change_24h': -369964131.5727577,
#  'market_cap_change_percentage_24h': -2.27794,
#  'circulating_supply': 15843541913.347,
#  'total_supply': 15843541913.347,
#  'max_supply': None,
#  'ath': 1.049,
#  'ath_change_percentage': -4.51546,
#  'ath_date': '2026-03-09T17:00:25.937Z',
#  'atl': 0.155357,
#  'atl_change_percentage': 544.80434,
#  'atl_date': '2025-10-31T14:27:24.456Z',
#  'roi': None,
#  'last_updated': '2026-03-20T08:07:48.448Z'}

# %%
coin_market_data = CoinMarketData(**response[10])
print(coin_market_data)
import polars as pl
print(pl.DataFrame(coin_market_data.model_dump()))
# Out:
# id='whitebit' symbol='wbt' name='WhiteBIT Coin' image='https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096' current_price=55.12 market_cap=11762199929.0 market_cap_rank=11 fully_diluted_valuation=17631773648.0 total_volume=72176590.0 high_24h=56.12 low_24h=54.65 price_change_24h=-0.9966356811185264 price_change_percentage_24h=-1.7761 market_cap_change_24h=-214336551.0865841 market_cap_change_percentage_24h=-1.78964 circulating_supply=213418274.0 total_supply=319918274.0 max_supply=400000000.0 ath=64.11 ath_change_percentage=-13.83964 ath_date=datetime.datetime(2025, 12, 10, 20, 16, 13, 582000, tzinfo=TzInfo(0)) atl=3.06 atl_change_percentage=1704.0256 atl_date=datetime.datetime(2023, 2, 13, 19, 1, 21, 899000, tzinfo=TzInfo(0)) roi=None last_updated=datetime.datetime(2026, 3, 20, 10, 19, 57, 808000, tzinfo=TzInfo(0))
# shape: (1, 26)
# ┌──────────┬────────┬─────────────┬─────────────┬───┬─────────────┬────────────┬──────┬────────────┐
# ...
